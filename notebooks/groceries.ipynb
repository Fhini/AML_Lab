# %%
import numpy as np
import pandas as p
import matplotlib.pyplot as plt

# %%
Data = p.read_csv('../data/Groceries_dataset.csv')
dataset = Data
dataset
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
dataset.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
dataset = dataset.drop_duplicates()

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset
x = dataset.iloc[:, 2:6].values
x
# Out:
# array([['tropical fruit'],
#        ['whole milk'],
#        ['pip fruit'],
#        ...,
#        ['cake bar'],
#        ['fruit/vegetable juice'],
#        ['cat food']], shape=(38006, 1), dtype=object)

# %%
y = dataset.iloc[:, -1].values
y
# Out:
# <StringArray>
# [          'tropical fruit',               'whole milk',
#                 'pip fruit',         'other vegetables',
#                'whole milk',               'rolls/buns',
#          'other vegetables',               'pot plants',
#                'whole milk',           'tropical fruit',
#  ...
#             'bottled water',    'fruit/vegetable juice',
#                'rolls/buns', 'long life bakery product',
#                       'oil',            'sliced cheese',
#                     'candy',                 'cake bar',
#     'fruit/vegetable juice',                 'cat food']
# Length: 38006, dtype: str

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 45)

# %%
x_test
# Out:
# array([['herbs'],
#        ['other vegetables'],
#        ['canned fruit'],
#        ...,
#        ['frozen vegetables'],
#        ['brown bread'],
#        ['whole milk']], shape=(7602, 1), dtype=object)

# %%
from sklearn import tree
#clf = tree.DecisionTreeClassifier(criterion='entropy', random_state=0)
clf_gini = tree.DecisionTreeClassifier(criterion='gini')
clf_gini.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 4
#       1 from sklearn import tree
#       2 #clf = tree.DecisionTreeClassifier(criterion='entropy', random_state=0)
#       3 clf_gini = tree.DecisionTreeClassifier(criterion='gini')
# ----> 4 clf_gini.fit(x_train, y_train)
#
# File c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py:1018, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     987 @_fit_context(prefer_skip_nested_validation=True)
#     988 def fit(self, X, y, sample_weight=None, check_input=True):
#     989     """Build a decision tree classifier from the training set (X, y).
#     990
#     991     Parameters
#    (...)   1015         Fitted estimator.
#    1016     """
# -> 1018     super()._fit(
#    1019         X,
#    1020         y,
#    1021         sample_weight=sample_weight,
#    1022         check_input=check_input,
#    1023     )
#    1024     return self
#
# File c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py:247, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     243 check_X_params = dict(
#     244     dtype=np.float32, accept_sparse="csc", ensure_all_finite=False
#     245 )
#     246 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 247 X, y = validate_data(
#     248     self, X, y, validate_separately=(check_X_params, check_y_params)
#     249 )
#     251 missing_values_in_feature_mask = (
#     252     self._compute_missing_values_in_feature_mask(X)
#     253 )
#     254 if issparse(X):
#
# File c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:3050, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3048 if "estimator" not in check_X_params:
#    3049     check_X_params = {**default_check_params, **check_X_params}
# -> 3050 X = check_array(X, input_name="X", **check_X_params)
#    3051 if "estimator" not in check_y_params:
#    3052     check_y_params = {**default_check_params, **check_y_params}
#
# File c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1035, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1033         array = xp.astype(array, dtype, copy=False)
#    1034     else:
# -> 1035         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1036 except ComplexWarning as complex_warning:
#    1037     raise ValueError(
#    1038         "Complex data not supported\n{}\n".format(array)
#    1039     ) from complex_warning
#
# File c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py:976, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     974     array = numpy.array(array, order=order, dtype=dtype)
#     975 else:
# --> 976     array = numpy.asarray(array, order=order, dtype=dtype)
#     978 # At this point array is a NumPy ndarray. We convert it to an array
#     979 # container that is consistent with the input's namespace.
#     980 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'rolls/buns'

# %%
from sklearn import tree
#clf = tree.DecisionTreeClassifier(criterion='entropy', random_state=0)
clf_entropy = tree.DecisionTreeClassifier(criterion='entropy')
clf_entropy.fit(x_train, y_train)

# %%
y_pred_gini = clf_gini.predict(x_test)
y_pred_entropy = clf_entropy.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm_gini = confusion_matrix(y_test, y_pred_gini)
cm_gini

# %%
from sklearn.metrics import confusion_matrix
cm_entropy = confusion_matrix(y_test, y_pred_entropy)
cm_entropy

# %%
from sklearn.metrics import accuracy_score
accuracy_gini = accuracy_score(y_test, y_pred_gini)*100
accuracy_gini

# %%
from sklearn.metrics import accuracy_score
accuracy_entropy = accuracy_score(y_test, y_pred_entropy)*100
accuracy_entropy

# %%
from sklearn import tree
tree.plot_tree(clf_gini)

# %%
from sklearn import tree
tree.plot_tree(clf_entropy)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

test_sizes = [0.2, 0.25, 0.3]

for test_size in test_sizes:

    print("====================================")
    print("Test Size:", test_size)
    print("Training:", int((1-test_size)*100), "%")
    print("Testing :", int(test_size*100), "%")
    
    # Split data
    x_train, x_test, y_train, y_test = train_test_split(
        x, y,
        test_size=test_size,
        random_state=45
    )

    # Decision Tree - Gini
    clf_gini = DecisionTreeClassifier(
        criterion="gini",
        random_state=45
    )
    clf_gini.fit(x_train, y_train)

    y_pred_gini = clf_gini.predict(x_test)
    accuracy_gini = accuracy_score(y_test, y_pred_gini) * 100

    # Decision Tree - Entropy
    clf_entropy = DecisionTreeClassifier(
        criterion="entropy",
        random_state=45
    )
    clf_entropy.fit(x_train, y_train)

    y_pred_entropy = clf_entropy.predict(x_test)
    accuracy_entropy = accuracy_score(y_test, y_pred_entropy) * 100

    print("Gini Accuracy   :", accuracy_gini, "%")
    print("Entropy Accuracy:", accuracy_entropy, "%")
